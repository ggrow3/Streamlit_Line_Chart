# %%
import pandas as pd
from pandas_datareader import data


stocks = {"LIT":"Lithium","USO":"United","UNG":"Natural Gas Fund","USL":"US 12 Month Natural Gas Fund (UNL)"}      



def get_stock_df(symbol,start,end):
   source = 'yahoo'
   df = data.DataReader(
      symbol, start=start, end=end, data_source=source
   )
   return df

def get_stock_combined(symbols,start,end):
   dfs = []
   for symbol in symbols.keys():
      df = get_stock_df(symbol,start,end)
      df['Symbol'] = symbol
      df['SymbolFullName'] = symbols[symbol]
      dfs.append(df)
   df_combined = pd.concat(dfs, axis=0)
   df_combined['date'] = df_combined.index.values
   return df_combined


def get_stock_title(stocks):
   title = ""
   idx = 0
   
   for i in stocks.keys():
      title = title + stocks[i] 
  
      if idx <  len(stocks.keys()) - 1: 
         title = title + " & "
      idx = idx + 1
      
   return title

# %%
stock_title = get_stock_title(stocks)
start = '2021-06-01'
end = '2022-08-01'

df_combined = get_stock_combined(stocks,start,end)

print(df_combined)
# Out:
#                  High        Low       Open      Close    Volume  Adj Close  \
# Date
# 2021-06-01  68.279999  67.470001  67.500000  67.919998  904000.0  67.767120
# 2021-06-02  68.199997  67.779999  68.070000  68.199997  607700.0  68.046494
# 2021-06-03  67.580002  66.809998  67.580002  67.139999  750600.0  66.988876
# 2021-06-04  69.180000  67.900002  68.059998  69.120003  690300.0  68.964432
# 2021-06-07  68.930000  68.080002  68.699997  68.669998  790900.0  68.515434
# ...               ...        ...        ...        ...       ...        ...
# 2022-04-13  39.639999  38.410000  39.029999  39.590000   39800.0  39.590000
# 2022-04-14  40.259998  38.650002  38.650002  39.900002   31000.0  39.900002
# 2022-04-18  40.799999  40.110001  40.250000  40.200001   51700.0  40.200001
# 2022-04-19  39.209999  38.310001  39.160000  38.450001   51000.0  38.450001
# 2022-04-20  39.035000  38.119999  38.790001  38.759998   67061.0  38.759998
#
#            Symbol                      SymbolFullName       date
# Date
# 2021-06-01    LIT                             Lithium 2021-06-01
# 2021-06-02    LIT                             Lithium 2021-06-02
# 2021-06-03    LIT                             Lithium 2021-06-03
# 2021-06-04    LIT                             Lithium 2021-06-04
# 2021-06-07    LIT                             Lithium 2021-06-07
# ...           ...                                 ...        ...
# 2022-04-13    USL  US 12 Month Natural Gas Fund (UNL) 2022-04-13
# 2022-04-14    USL  US 12 Month Natural Gas Fund (UNL) 2022-04-14
# 2022-04-18    USL  US 12 Month Natural Gas Fund (UNL) 2022-04-18
# 2022-04-19    USL  US 12 Month Natural Gas Fund (UNL) 2022-04-19
# 2022-04-20    USL  US 12 Month Natural Gas Fund (UNL) 2022-04-20
#
# [900 rows x 9 columns]

# %%
#USO
import pandas as pd
from pandas_datareader import data
 

stocks = {"LIT":"Lithium","USO":"United States Oil ETF","UNG":"Natural Gas Fund","USL":"US 12 Month Natural Gas Fund (UNL)"}      
stock_title = get_stock_title(stocks)
start = '2021-06-01'
end = '2022-08-01'

df_combined = get_stock_combined(stocks,start,end)
base = alt.Chart(df_combined)

line = base.mark_line().encode(
    alt.X("date", title="Date"),
    alt.Y("Close", title="Closing Price", scale=alt.Scale(zero=False)),
    color='SymbolFullName'
).properties(
    height=400, width=600,
    title=stock_title
).configure_title(
    fontSize=16
).configure_axis(
    titleFontSize=14,
    labelFontSize=12
)

line
# Out:
# alt.Chart(...)

# %%
df_combined = get_stock_combined(stocks.keys(),start,end)

base =  alt.Chart(df_combined).mark_line().encode(
    x='date',
    y='Close',
    color='Symbol')
base
# Out:
# alt.Chart(...)

# %%
import altair as alt
from vega_datasets import data

source = df_combined

print(source)

base = alt.Chart(source).properties(width=550)

line = base.mark_line().encode(
    x='date',
    y='Close',
    color='SymbolFullName'
)

rule = base.mark_rule().encode(
    y='average(Close)',
    color='Symbol',
    size=alt.value(2)
)

line + rule
# Out:
#                  High        Low       Open      Close    Volume  Adj Close  \
# Date
# 2021-06-01  68.279999  67.470001  67.500000  67.919998  904000.0  67.767120
# 2021-06-02  68.199997  67.779999  68.070000  68.199997  607700.0  68.046494
# 2021-06-03  67.580002  66.809998  67.580002  67.139999  750600.0  66.988876
# 2021-06-04  69.180000  67.900002  68.059998  69.120003  690300.0  68.964432
# 2021-06-07  68.930000  68.080002  68.699997  68.669998  790900.0  68.515434
# ...               ...        ...        ...        ...       ...        ...
# 2022-04-13  39.639999  38.410000  39.029999  39.590000   39800.0  39.590000
# 2022-04-14  40.259998  38.650002  38.650002  39.900002   31000.0  39.900002
# 2022-04-18  40.799999  40.110001  40.250000  40.200001   51700.0  40.200001
# 2022-04-19  39.209999  38.310001  39.160000  38.450001   51000.0  38.450001
# 2022-04-20  39.035000  38.119999  38.790001  38.759998   67061.0  38.759998
#
#            Symbol                      SymbolFullName       date
# Date
# 2021-06-01    LIT                             Lithium 2021-06-01
# 2021-06-02    LIT                             Lithium 2021-06-02
# 2021-06-03    LIT                             Lithium 2021-06-03
# 2021-06-04    LIT                             Lithium 2021-06-04
# 2021-06-07    LIT                             Lithium 2021-06-07
# ...           ...                                 ...        ...
# 2022-04-13    USL  US 12 Month Natural Gas Fund (UNL) 2022-04-13
# 2022-04-14    USL  US 12 Month Natural Gas Fund (UNL) 2022-04-14
# 2022-04-18    USL  US 12 Month Natural Gas Fund (UNL) 2022-04-18
# 2022-04-19    USL  US 12 Month Natural Gas Fund (UNL) 2022-04-19
# 2022-04-20    USL  US 12 Month Natural Gas Fund (UNL) 2022-04-20
#
# [900 rows x 9 columns]
# alt.LayerChart(...)
